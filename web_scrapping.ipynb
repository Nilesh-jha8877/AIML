# %% [markdown]
# <a href="https://colab.research.google.com/github/Nilesh-jha8877/AIML/blob/main/web_scrapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
URL= "https://stephen-king-api.onrender.com/api/books"
res=requests.get(URL)

# %%
if res.status_code==200:
  print(res.headers)

  with open("scraped_data","w") as f:
    f.write(res.text)
# Out:
# {'Date': 'Sun, 12 Jul 2026 10:50:41 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'access-control-allow-origin': '*', 'Content-Encoding': 'br', 'etag': 'W/"6a84-LfTIQ2MqFHkZM3CicF+7eyeHW3I"', 'rndr-id': '33a73259-d504-45fb', 'Server': 'cloudflare', 'vary': 'Accept-Encoding', 'x-powered-by': 'Express', 'x-render-origin-server': 'Render', 'cf-cache-status': 'DYNAMIC', 'CF-RAY': 'a19f7d01ec3444df-ATL', 'alt-svc': 'h3=":443"; ma=86400'}

# %%
json_data=res.json()

# %%
import pandas as pd
df=pd.json_normalize(json_data["data"])
df = df[['id', 'Title', 'Year', 'ISBN']]

# %%
df
# Out:
#     id            Title  Year                  ISBN
# 0    1           Carrie  1974     978-0-385-08695-0
# 1    2      Salem's Lot  1975     978-0-385-00751-1
# 2    3      The Shining  1977     978-0-385-12167-5
# 3    4             Rage  1977     978-0-451-07645-8
# 4    5        The Stand  1978     978-0-385-12168-2
# ..  ..              ...   ...                   ...
# 59  60        Elevation  2018     978-1-98210-231-9
# 60  61    The Institute  2019     978-1-98211-056-7
# 61  62            Later  2021     978-1-78909-649-1
# 62  63    Billy Summers  2021     978-1-982-17361-6
# 63  72  The Roopak Zone  1979  978-0-670-26069697-5
#
# [64 rows x 4 columns]

# %%
from bs4 import BeautifulSoup
with open("scraped_data","r")as f:
  html_content=f.read()
  soup=BeautifulSoup(html_content,"lxml")

# %%
all_h3=soup.find_all("h3")

for h3 in all_h3:
  name=h3.get_text(strip=True)
  # print(h3.find_parent("div")["class"])
  population=h3.find_next("div").select("span.country_population")[0].get_text(strip=True)
